# %% [markdown]
# # Setup use case Wine

# %%
import requests
from io import BytesIO
from IPython.display import Image, display
from PIL import Image as pil_image

file_url = 'https://psitron.s3.ap-southeast-1.amazonaws.com/Machine+Learning+Operations+(MLOps)+Specialization+Course+Jan+2023/GCP+vertex+ai+piplines.png'
response = requests.get(file_url)
pil_img = pil_image.open(BytesIO(response.content)).convert('RGB')

display(pil_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1896x972>

# %% [markdown]
# ### Set up the auto completion

# %%
#install auto-completion 
# !pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
from jedi import settings
settings.case_insensitive_completion = True
# Out:
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# Requirement already satisfied: jupyter_contrib_nbextensions in /opt/conda/lib/python3.7/site-packages (0.7.0)
# Requirement already satisfied: nbconvert>=6.0 in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (7.2.9)
# Requirement already satisfied: traitlets>=4.1 in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (5.9.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: tornado in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (6.2)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (4.9.2)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (0.6.1)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: notebook>=6.0 in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (6.5.3)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (4.12.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (67.6.0)
# Requirement already satisfied: pyyaml in ./.local/lib/python3.7/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (5.4.1)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.14.0)
# Requirement already satisfied: nbformat>=5.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.7.3)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.11.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (6.0.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (6.0.0)
# Requirement already satisfied: jinja2>=3.0 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: markupsafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.2)
# Requirement already satisfied: packaging in ./.local/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (21.3)
# Requirement already satisfied: jupyter-client>=5.3.4 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (7.4.9)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.5.6)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (6.16.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.5.3)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (25.0.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbconvert>=6.0->jupyter_contrib_nbextensions) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.7/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.7/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.7/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.23.6)
# Requirement already satisfied: notebook-shim>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.7/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.7/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.17.3)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.7/site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.7/site-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: debugpy>=1.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.6)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (7.34.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.9)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.18.2)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.38)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (22.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (5.12.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.3.10)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (1.15.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.6)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# [I 10:01:23 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 10:01:23 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input -> hide_input
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hide_input/hide-input.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hide_input/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hide_input/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hide_input/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad -> scratchpad
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/scratchpad.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/demo.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/LICENSE
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/scratchpad.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/gist_it -> gist_it
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/gist_it/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/gist_it/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/gist_it/gist_it.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/gist_it/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding -> codefolding
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_unfolded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-fold.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_unfolded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_folded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/foldgutter.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_1.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-unfolded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-folded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/edit.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_2.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/firstline-fold.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/blockcomment-fold.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding -> codefolding
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_unfolded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-fold.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_unfolded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_folded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/foldgutter.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_1.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-unfolded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-folded.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/edit.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_2.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/firstline-fold.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/blockcomment-fold.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hinterland -> hinterland
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hinterland/hinterland.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hinterland/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hinterland/hinterland.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/load_tex_macros -> load_tex_macros
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/load_tex_macros/load_tex_macros.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/load_tex_macros/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/load_tex_macros/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/load_tex_macros/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/printview -> printview
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/printview/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/printview/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/printview/printview-button.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/printview/printview.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/printview/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/datestamper -> datestamper
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/datestamper/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/datestamper/main.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/datestamper/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/datestamper/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execution_dependencies -> execution_dependencies
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execution_dependencies/execution_dependencies.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execution_dependencies/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execution_dependencies/execution_dependencies.yml
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/addbefore -> addbefore
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/addbefore/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/addbefore/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/addbefore/addbefore.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/addbefore/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/spellchecker -> spellchecker
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/spellchecker/screenshot.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/spellchecker/config.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/spellchecker/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/spellchecker/main.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/spellchecker/download_new_dict.py
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/spellchecker/main.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/spellchecker/__pycache__/download_new_dict.cpython-37.pyc
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/spellchecker/typo/LICENSE.txt
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/spellchecker/typo/typo.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/runtools -> runtools
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/annotations.odg
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/runtools_nb.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/demo.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/main.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/runtools_execute.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/runtools_show_hide.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/gutter.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/runtools_lock.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/runtools_marker.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/runtools.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/cellstate.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/runtools/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time -> execute_time
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execute_time/execution-timings-menu.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execute_time/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execute_time/execution-timings-box.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/execute_time/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell -> go_to_current_running_cell
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/go_to_current_running_cell.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/jump_to_cell.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/auto_focus.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/anchor.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/eye.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/tree-filter -> tree-filter
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/tree-filter/index.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/tree-filter/tree-filter.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/tree-filter/demo.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/tree-filter/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband -> rubberband
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/rubberband/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/rubberband/main.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/rubberband/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/rubberband/rubberband.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/rubberband/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze -> freeze
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/freeze/config.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/freeze/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/freeze/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/freeze/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_header -> hide_header
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hide_header/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hide_header/hide_header.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/hide_header/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/snippets -> snippets
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets/snippets.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets/snippets-demo.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets/snippets.json
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/move_selected_cells -> move_selected_cells
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/move_selected_cells/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/move_selected_cells/move_selected_cells.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/move_selected_cells/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/skill -> skill
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/skill/skill.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/skill/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/skill/skill.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/skill/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/notify -> notify
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/notify/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/notify/notification.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/notify/notify.mp3
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/notify/notify.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/notify/notify.yaml
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap -> select_keymap
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/select_keymap/select_keymap.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/select_keymap/select_keymap.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/select_keymap/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/select_keymap/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_font_size -> code_font_size
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_font_size/code_font_size.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_font_size/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_font_size/code_font_size.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/livemdpreview -> livemdpreview
# ...
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codemirror_mode_extensions -> codemirror_mode_extensions
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codemirror_mode_extensions/codemirror_mode_extensions.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codemirror_mode_extensions/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/zenmode -> zenmode
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/main.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/zenmode.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/main.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/images/back22.jpg
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/images/ipynblogo0.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/images/back1.jpg
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/images/ipynblogo1.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/images/back2.jpg
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/images/back11.jpg
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/images/back21.jpg
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/images/back3.jpg
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/zenmode/images/back12.jpg
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings -> collapsible_headings
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/screenshot.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/main.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/collapsible_headings.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/navigation-hotkeys -> navigation-hotkeys
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/navigation-hotkeys/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/navigation-hotkeys/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/navigation-hotkeys/hotkeys.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/navigation-hotkeys/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/cell_filter -> cell_filter
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/cell_filter/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/cell_filter/cell_filter.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/cell_filter/cell_filter.yml
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/qtconsole -> qtconsole
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/qtconsole/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/qtconsole/qtconsole.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/qtconsole/qtconsole.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu -> snippets_menu
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/screenshot2.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/config.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenu_python.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/screenshot1.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/screenshot3.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/examples_for_custom.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/thumbnail.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/main.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenu_markdown.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_menu.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_functions.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_assumptions.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/h5py.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_constants.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/pandas.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numba.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_special.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/python.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/matplotlib.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/python_regex.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/astropy.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_polynomial.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_ufuncs.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/splitcell -> splitcell
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/splitcell/splitcell.js
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/splitcell/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/splitcell/splitcell.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/splitcell/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering -> equation-numbering
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/info.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/button.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/export_embedded -> export_embedded
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/export_embedded/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/export_embedded/export_embedded.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/export_embedded/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/export_embedded/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down -> scroll_down
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scroll_down/config.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scroll_down/icon.png
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scroll_down/readme.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/scroll_down/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/contrib_nbextensions_help_item -> contrib_nbextensions_help_item
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/contrib_nbextensions_help_item.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/table_beautifier -> table_beautifier
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/table_beautifier/table_beautifier.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/table_beautifier/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/table_beautifier/main.css
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/table_beautifier/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_highlight_selected_word/static/highlight_selected_word -> highlight_selected_word
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/highlight_selected_word/README.md
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/highlight_selected_word/configurator.yaml
# [I 10:01:23 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/highlight_selected_word/main.js
# [I 10:01:23 InstallContribNbextensionsApp] - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions items to config in /home/jupyter/.jupyter
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /home/jupyter/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.6.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
# [I 10:01:23 InstallContribNbextensionsApp] Enabling notebook extension contrib_nbextensions_help_item/main...
# [I 10:01:23 InstallContribNbextensionsApp]       - Validating: OK
# [I 10:01:23 InstallContribNbextensionsApp] - Editing config: /home/jupyter/.jupyter/jupyter_nbconvert_config.json
# [I 10:01:23 InstallContribNbextensionsApp] --  Configuring nbconvert template path
# [I 10:01:23 InstallContribNbextensionsApp] --  Configuring nbconvert preprocessors
# [I 10:01:23 InstallContribNbextensionsApp] - Writing config: /home/jupyter/.jupyter/jupyter_nbconvert_config.json
# [I 10:01:23 InstallContribNbextensionsApp] --  Writing updated config file /home/jupyter/.jupyter/jupyter_nbconvert_config.json

# %% [markdown]
# ### Set up the environment
# - Python 3
# - virtualenv
# - Jupyter notebook running in a virtual environment with Python 3
# - Docker
# - Git
# - Google Cloud SDK (gcloud)

# %% [markdown]
# ### Enable  the APIs if they are not enabled

# %%
# !gcloud services enable compute.googleapis.com         \
                       containerregistry.googleapis.com  \
                       aiplatform.googleapis.com  \
                       cloudbuild.googleapis.com \
                       cloudfunctions.googleapis.com
# Out:
# Operation "operations/acat.p2-531751153412-629a5d8a-d702-4d60-9ed7-6b37e2cff4cb" finished successfully.

# %% [markdown]
# ## Uncomment all needed cells if you need to install missing packages

# %%
# Install ai platform and kfp
USER_FLAG = "--user"
# !pip3 install {USER_FLAG} google-cloud-aiplatform==1.3.0 --upgrade
# !pip3 install {USER_FLAG} kfp --upgrade
# Out:
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# Collecting google-cloud-aiplatform==1.3.0
#   Using cached google_cloud_aiplatform-1.3.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.26.0 in ./.local/lib/python3.7/site-packages (from google-cloud-aiplatform==1.3.0) (1.34.0)
# Requirement already satisfied: google-cloud-bigquery<3.0.0dev,>=1.15.0 in ./.local/lib/python3.7/site-packages (from google-cloud-aiplatform==1.3.0) (2.34.4)
# Collecting google-cloud-storage<2.0.0dev,>=1.32.0
#   Using cached google_cloud_storage-1.44.0-py2.py3-none-any.whl (106 kB)
# Requirement already satisfied: proto-plus>=1.10.1 in /opt/conda/lib/python3.7/site-packages (from google-cloud-aiplatform==1.3.0) (1.22.2)
# Requirement already satisfied: packaging>=14.3 in ./.local/lib/python3.7/site-packages (from google-cloud-aiplatform==1.3.0) (21.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (2.28.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (1.58.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (2.16.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5 in ./.local/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (3.20.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (1.51.3)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in ./.local/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (1.47.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform==1.3.0) (2.3.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform==1.3.0) (2.4.1)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform==1.3.0) (2.8.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from google-cloud-storage<2.0.0dev,>=1.32.0->google-cloud-aiplatform==1.3.0) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging>=14.3->google-cloud-aiplatform==1.3.0) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.7/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform==1.3.0) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (3.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (0.4.8)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# Installing collected packages: google-cloud-storage, google-cloud-aiplatform
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 2.7.0
#     Uninstalling google-cloud-storage-2.7.0:
#       Successfully uninstalled google-cloud-storage-2.7.0
#   Attempting uninstall: google-cloud-aiplatform
#     Found existing installation: google-cloud-aiplatform 1.23.0
#     Uninstalling google-cloud-aiplatform-1.23.0:
#       Successfully uninstalled google-cloud-aiplatform-1.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-pipeline-components 1.0.40 requires google-cloud-aiplatform<2,>=1.14.0, but you have google-cloud-aiplatform 1.3.0 which is incompatible.
# google-cloud-pipeline-components 1.0.40 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# Successfully installed google-cloud-aiplatform-1.3.0 google-cloud-storage-1.44.0
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# Requirement already satisfied: kfp in ./.local/lib/python3.7/site-packages (1.8.19)
# Requirement already satisfied: click<9,>=7.1.2 in /opt/conda/lib/python3.7/site-packages (from kfp) (8.1.3)
# Requirement already satisfied: kfp-server-api<2.0.0,>=1.1.2 in ./.local/lib/python3.7/site-packages (from kfp) (1.8.5)
# Requirement already satisfied: absl-py<2,>=0.9 in /opt/conda/lib/python3.7/site-packages (from kfp) (1.4.0)
# Requirement already satisfied: jsonschema<5,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from kfp) (4.17.3)
# Requirement already satisfied: PyYAML<6,>=5.3 in ./.local/lib/python3.7/site-packages (from kfp) (5.4.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in ./.local/lib/python3.7/site-packages (from kfp) (1.34.0)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in ./.local/lib/python3.7/site-packages (from kfp) (0.10.1)
# Requirement already satisfied: cloudpickle<3,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from kfp) (2.2.1)
# Requirement already satisfied: google-api-python-client<2,>=1.7.8 in /opt/conda/lib/python3.7/site-packages (from kfp) (1.8.0)
# Requirement already satisfied: protobuf<4,>=3.13.0 in ./.local/lib/python3.7/site-packages (from kfp) (3.20.3)
# Requirement already satisfied: pydantic<2,>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from kfp) (1.10.6)
# Requirement already satisfied: google-cloud-storage<3,>=1.20.0 in ./.local/lib/python3.7/site-packages (from kfp) (1.44.0)
# Requirement already satisfied: docstring-parser<1,>=0.7.3 in ./.local/lib/python3.7/site-packages (from kfp) (0.15)
# Requirement already satisfied: google-auth<3,>=1.6.1 in /opt/conda/lib/python3.7/site-packages (from kfp) (2.16.2)
# Requirement already satisfied: typing-extensions<5,>=3.7.4 in /opt/conda/lib/python3.7/site-packages (from kfp) (4.5.0)
# Requirement already satisfied: fire<1,>=0.3.1 in ./.local/lib/python3.7/site-packages (from kfp) (0.5.0)
# Requirement already satisfied: strip-hints<1,>=0.1.8 in ./.local/lib/python3.7/site-packages (from kfp) (0.1.10)
# Requirement already satisfied: typer<1.0,>=0.3.2 in /opt/conda/lib/python3.7/site-packages (from kfp) (0.7.0)
# Requirement already satisfied: tabulate<1,>=0.8.6 in /opt/conda/lib/python3.7/site-packages (from kfp) (0.9.0)
# Requirement already satisfied: uritemplate<4,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from kfp) (3.0.1)
# Requirement already satisfied: kubernetes<20,>=8.0.0 in ./.local/lib/python3.7/site-packages (from kfp) (19.15.0)
# Requirement already satisfied: Deprecated<2,>=1.2.7 in /opt/conda/lib/python3.7/site-packages (from kfp) (1.2.13)
# Requirement already satisfied: kfp-pipeline-spec<0.2.0,>=0.1.16 in ./.local/lib/python3.7/site-packages (from kfp) (0.1.16)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from click<9,>=7.1.2->kfp) (6.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.7/site-packages (from Deprecated<2,>=1.2.7->kfp) (1.15.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.7/site-packages (from fire<1,>=0.3.1->kfp) (2.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from fire<1,>=0.3.1->kfp) (1.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/conda/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp) (1.58.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp) (2.28.2)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client<2,>=1.7.8->kfp) (0.20.4)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client<2,>=1.7.8->kfp) (0.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<3,>=1.6.1->kfp) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<3,>=1.6.1->kfp) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<3,>=1.6.1->kfp) (4.9)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-storage<3,>=1.20.0->kfp) (2.3.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-storage<3,>=1.20.0->kfp) (2.4.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp) (5.12.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp) (22.2.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp) (1.3.10)
# Requirement already satisfied: urllib3>=1.15 in /opt/conda/lib/python3.7/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp) (1.26.14)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.7/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp) (2.8.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.7/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp) (2022.12.7)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.7/site-packages (from kubernetes<20,>=8.0.0->kfp) (1.3.1)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.7/site-packages (from kubernetes<20,>=8.0.0->kfp) (67.6.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/lib/python3.7/site-packages (from kubernetes<20,>=8.0.0->kfp) (1.5.1)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from strip-hints<1,>=0.1.8->kfp) (0.38.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.7/site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage<3,>=1.20.0->kfp) (1.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.7/site-packages (from httplib2<1dev,>=0.9.2->google-api-python-client<2,>=1.7.8->kfp) (3.0.9)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.7/site-packages (from importlib-resources>=1.4.0->jsonschema<5,>=3.0.1->kfp) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.1->kfp) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp) (3.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from requests-oauthlib->kubernetes<20,>=8.0.0->kfp) (3.2.2)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -rpcio-status (/opt/conda/lib/python3.7/site-packages)

# %%
# !pip install google-cloud-pipeline-components --user

# %%
# Restart the kernel
import os

if not os.getenv("IS_TESTING"):
    # Automatically restart kernel after installs
    import IPython

    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

# %% [markdown]
# #### Set up the global variables

# %%
PATH=%env PATH
# %env PATH={PATH}:/home/jupyter/.local/bin
REGION="europe-west1"

# Get projet name
shell_output=!gcloud config get-value project 2> /dev/null
PROJECT_ID=shell_output[0]

# Set bucket name
BUCKET_NAME="gs://"+PROJECT_ID+"-bucket-winequality"

# Create bucket
PIPELINE_ROOT = f"{BUCKET_NAME}/pipeline_root_wine/"
PIPELINE_ROOT

USER_FLAG = "--user"
# Out:
# env: PATH=/usr/local/cuda/bin:/opt/conda/bin:/opt/conda/condabin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/home/jupyter/.local/bin:/home/jupyter/.local/bin

# %% [markdown]
# ## Import Libraries
#  * Artifact,
#  * Dataset,
#  * Input,
#  * Model,
#  * Output,
#  * Metrics,
#  * ClassificationMetrics
#  * InputPath
#  * OutputPath

# %%
from typing import NamedTuple
import typing
from kfp.v2 import dsl
from kfp.v2.dsl import (Artifact,
                        Dataset,
                        Input,
                        Model,
                        Output,
                        Metrics,
                        ClassificationMetrics,
                        component, 
                        OutputPath, 
                        InputPath)

from kfp.v2 import compiler
from google.cloud import bigquery
from google.cloud import aiplatform
from google.cloud.aiplatform import pipeline_jobs
from google_cloud_pipeline_components import aiplatform as gcc_aip

# %% [markdown]
# ### Create pipeline
#
# We create 4 components:
# - Load data
# - Train a  model
# - Evaluate the model
# - Deploy the model
#
# The components have dependencies on `pandas`, `sklearn`.

# %%
# List columns
import pandas as pd
df_wine = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", delimiter=";")
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %% [markdown]
# Available columns:
# - volatile acidity :   Volatile acidity is the gaseous acids present in wine.
# - fixed acidity :   Primary fixed acids found in wine are tartaric, succinic, citric, and malic
# - residual sugar :   Amount of sugar left after fermentation.
# - citric acid :    It is weak organic acid, found in citrus fruits naturally.
# - chlorides :   Amount of salt present in wine.
# - free sulfur dioxide :   So2 is used for prevention of wine by oxidation and microbial spoilage.
# - total sulfur dioxide
# - pH :   In wine pH is used for checking acidity
# - density
# - sulphates :    Added sulfites preserve freshness and protect wine from oxidation, and bacteria.
# - alcohol :   Percent of alcohol present in wine.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.0.2

# %% [markdown]
# ### Read the wine quality dataset

# %%
#@component decorator in a Python script to define a Kubeflow 
@component(
    packages_to_install=["pandas", "pyarrow", "scikit-learn==1.0.2"],
    base_image="python:3.9",
    output_component_file="get_wine_data.yaml"
)

def get_wine_data(
    url: str,
    dataset_train: Output[Dataset],
    dataset_test: Output[Dataset]
):
    import pandas as pd
    import numpy as np
    from sklearn.model_selection import train_test_split as tts
    
    df_wine = pd.read_csv(url, delimiter=";")
    df_wine['best_quality'] = [ 1 if x>=7 else 0 for x in df_wine.quality] 
    df_wine['target'] = df_wine.best_quality
    df_wine = df_wine.drop(['quality', 'total sulfur dioxide', 'best_quality'], axis=1)
   
   
    train, test = tts(df_wine, test_size=0.3)
    train.to_csv(dataset_train.path + ".csv" , index=False, encoding='utf-8-sig')
    test.to_csv(dataset_test.path + ".csv" , index=False, encoding='utf-8-sig')

# %% [markdown]
# #### Train the wine quality model

# %%
@component(
    packages_to_install = [
        "pandas",
        "scikit-learn==1.0.2"
    ], base_image="python:3.9",
)
def train_winequality(
    dataset:  Input[Dataset],
    model: Output[Model], 
):
    
    from sklearn.ensemble import RandomForestClassifier
    import pandas as pd
    import pickle

    data = pd.read_csv(dataset.path+".csv")
    model_rf = RandomForestClassifier(n_estimators=10)
    model_rf.fit(
        data.drop(columns=["target"]),
        data.target,
    )
    model.metadata["framework"] = "RF"
    file_name = model.path + f".pkl"
    with open(file_name, 'wb') as file:  
        pickle.dump(model_rf, file)

# %% [markdown]
# #### Evaluate the model

# %%
@component(
    packages_to_install = [
        "pandas",
        "scikit-learn==1.0.2"
    ], base_image="python:3.9",
)
def winequality_evaluation(
    test_set:  Input[Dataset],
    rf_winequality_model: Input[Model],
    thresholds_dict_str: str,
    metrics: Output[ClassificationMetrics],
    kpi: Output[Metrics]
) -> NamedTuple("output", [("deploy", str)]):

    from sklearn.ensemble import RandomForestClassifier
    import pandas as pd
    import logging 
    import pickle
    from sklearn.metrics import roc_curve, confusion_matrix, accuracy_score
    import json
    import typing

    
    def threshold_check(val1, val2):
        cond = "false"
        if val1 >= val2 :
            cond = "true"
        return cond

    data = pd.read_csv(test_set.path+".csv")
    model = RandomForestClassifier()
    file_name = rf_winequality_model.path + ".pkl"
    with open(file_name, 'rb') as file:  
        model = pickle.load(file)
    
    y_test = data.drop(columns=["target"])
    y_target=data.target
    y_pred = model.predict(y_test)
    

    y_scores =  model.predict_proba(data.drop(columns=["target"]))[:, 1]
    fpr, tpr, thresholds = roc_curve(
         y_true=data.target.to_numpy(), y_score=y_scores, pos_label=True
    )
    metrics.log_roc_curve(fpr.tolist(), tpr.tolist(), thresholds.tolist())  
    
    metrics.log_confusion_matrix(
       ["False", "True"],
       confusion_matrix(
           data.target, y_pred
       ).tolist(), 
    )
    
    accuracy = accuracy_score(data.target, y_pred.round())
    thresholds_dict = json.loads(thresholds_dict_str)
    rf_winequality_model.metadata["accuracy"] = float(accuracy)
    kpi.log_metric("accuracy", float(accuracy))
    deploy = threshold_check(float(accuracy), int(thresholds_dict['roc']))
    return (deploy,)

# %% [markdown]
# ### Deploy model

# %%
@component(
    packages_to_install=["google-cloud-aiplatform", "scikit-learn==1.0.2",  "kfp"],
    #base_image="europe-west1-docker.pkg.dev/PROJECT_ID/wine-train/scikit-learn-winequality:latest",
    base_image="python:3.9",
    output_component_file="model_winequality_coponent.yml"
)
def deploy_winequality(
    model: Input[Model],
    project: str,
    region: str,
    serving_container_image_uri : str, 
    vertex_endpoint: Output[Artifact],
    vertex_model: Output[Model]
):
    from google.cloud import aiplatform
    aiplatform.init(project=project, location=region)

    DISPLAY_NAME  = "winequality"
    MODEL_NAME = "winequality-rf"
    ENDPOINT_NAME = "winequality_endpoint"
    
    def create_endpoint():
        endpoints = aiplatform.Endpoint.list(
        filter='display_name="{}"'.format(ENDPOINT_NAME),
        order_by='create_time desc',
        project=project, 
        location=region,
        )
        if len(endpoints) > 0:
            endpoint = endpoints[0]  # most recently created
        else:
            endpoint = aiplatform.Endpoint.create(
            display_name=ENDPOINT_NAME, project=project, location=region
        )
    endpoint = create_endpoint()   
    
    
    #Import a model programmatically
    model_upload = aiplatform.Model.upload(
        display_name = DISPLAY_NAME, 
        artifact_uri = model.uri.replace("model", ""),
        serving_container_image_uri =  serving_container_image_uri,
        serving_container_health_route=f"/v1/models/{MODEL_NAME}",
        serving_container_predict_route=f"/v1/models/{MODEL_NAME}:predict",
        serving_container_environment_variables={
        "MODEL_NAME": MODEL_NAME,
    },       
    )
    model_deploy = model_upload.deploy(
        machine_type="n1-standard-4", 
        endpoint=endpoint,
        traffic_split={"0": 100},
        deployed_model_display_name=DISPLAY_NAME,
    )

    # Save data to the output params
    vertex_model.uri = model_deploy.resource_name

# %%
from datetime import datetime

TIMESTAMP =datetime.now().strftime("%Y%m%d%H%M%S")
DISPLAY_NAME = 'pipeline-winequality-job{}'.format(TIMESTAMP)

# %% [markdown]
# #### Create the Pipeline
#
# Once you have created all the needed components define the pipeline and then compile it into a `.json` file.

# %%
@dsl.pipeline(
    # Default pipeline root. You can override it when submitting the pipeline.
    pipeline_root=PIPELINE_ROOT,
    # A name for the pipeline. Use to determine the pipeline Context.
    name="pipeline-winequality",
    
)
def pipeline(
    url: str = "http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv",
    project: str = PROJECT_ID,
    region: str = REGION, 
    display_name: str = DISPLAY_NAME,
    api_endpoint: str = REGION+"-aiplatform.googleapis.com",
    thresholds_dict_str: str = '{"roc":0.8}',
    serving_container_image_uri: str = "europe-docker.pkg.dev/vertex-ai/prediction/sklearn-cpu.0-24:latest"
    ):
    
    data_op = get_wine_data(url)
    train_model_op = train_winequality(data_op.outputs["dataset_train"])
    model_evaluation_op = winequality_evaluation(
        test_set=data_op.outputs["dataset_test"],
        rf_winequality_model=train_model_op.outputs["model"],
        thresholds_dict_str = thresholds_dict_str, # I deploy the model anly if the model performance is above the threshold
    )
    
    with dsl.Condition(
        model_evaluation_op.outputs["deploy"]=="true",
        name="deploy-winequality",
    ):
           
        deploy_model_op = deploy_winequality(
        model=train_model_op.outputs['model'],
        project=project,
        region=region, 
        serving_container_image_uri = serving_container_image_uri,
        )

# %% [markdown]
# ### Compile and run the pipeline

# %%
compiler.Compiler().compile(pipeline_func=pipeline,
        package_path='ml_winequality.json')
# Out:
# /home/jupyter/.local/lib/python3.7/site-packages/kfp/v2/compiler/compiler.py:1293: FutureWarning: APIs imported from the v1 namespace (e.g. kfp.dsl, kfp.components, etc) will not be supported by the v2 compiler since v2.0.0
#   category=FutureWarning,

# %% [markdown]
# The pipeline compilation generates the **ml_winequality.json** job spec file.

# %%
### Create a run

# %%
start_pipeline = pipeline_jobs.PipelineJob(
    display_name="winequality-pipeline",
    template_path="ml_winequality.json",
    enable_caching=False,
    location=REGION,
)

# %%
start_pipeline.run()
# Out:
# Creating PipelineJob
# PipelineJob created. Resource name: projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326
# To use this PipelineJob in another session:
# pipeline_job = aiplatform.PipelineJob.get('projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326')
# View Pipeline Job:
# https://console.cloud.google.com/vertex-ai/locations/europe-west1/pipelines/runs/pipeline-winequality-20230318100326?project=531751153412
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob run completed. Resource name: projects/531751153412/locations/europe-west1/pipelineJobs/pipeline-winequality-20230318100326

# %% [markdown]
# ### List all models

# %%
DISPLAY_NAME = "winequality"
! gcloud ai models list --region={REGION} --filter={DISPLAY_NAME}
# Out:
# Using endpoint [https://europe-west1-aiplatform.googleapis.com/]
# MODEL_ID             DISPLAY_NAME
# 7868782507527766016  winequality

# %% [markdown]
# ### Schedule pipeline

# %% [markdown]
# The scheduled jobs are supported by the Cloud Scheduler and Cloud Functions.
# Check that the APIs Cloud Scheduler, Cloud Functions are enabled.

# %% [markdown]
# ### Run recurrent pipeline

# %%
from kfp.v2.google.client import AIPlatformClient

api_client = AIPlatformClient(
                project_id=PROJECT_ID,
                region=REGION,
                )

SERVICE_ACCOUNT = (
    "196303161359-compute@developer.gserviceaccount.com" 
)
response = api_client.create_schedule_from_job_spec(
    enable_caching=True,
    job_spec_path="ml_winequality.json",
    schedule="0 0 * * 1", #once per week on Monday
    #schedule= "0 * * * *", #Every hour
    time_zone="Europe/Brussels",  # change this as necessary
    parameter_values={"display_name": DISPLAY_NAME},
    pipeline_root=PIPELINE_ROOT,  # this argument is necessary if you did not specify PIPELINE_ROOT as part of the pipeline definition.
    #service_account=SERVICE_ACCOUNT,
    
)

# %% [markdown]
# Once the scheduled job is created, you can see it listed in the Cloud Scheduler panel in the Console.

# %% [markdown]
# ### Test the batch prediction

# %%
## Optional Don't run
# Define variables 
job_display_name = "winequality-batch-prediction-job"
MODEL_NAME="winequality"
ENDPOINT_NAME="winequality_endpoint"
BUCKET_URI="gs://your-bucket-winequality/pipeline_root_wine/332188XXXX/pipeline-winequality-20211227155508/get-wine-data_8271177375014715392"
input_file_name="test.csv"

# Get model id
MODEL_ID=!(gcloud ai models list --region=$REGION \
           --filter=display_name=$MODEL_NAME)
MODEL_ID=MODEL_ID[2].split(" ")[0]

model_resource_name = f'projects/{PROJECT_ID}/locations/{REGION}/models/{MODEL_ID}'
gcs_source= [f"{BUCKET_URI}/{input_file_name}"]
gcs_destination_prefix=f"{BUCKET_URI}/output"

def batch_prediction_job(
    project: str,
    location: str,
    model_resource_name: str,
    job_display_name: str,
    gcs_source: str,
    gcs_destination_prefix: str,
    machine_type: str,
    starting_replica_count: int = 1, # The number of nodes for this batch prediction job. 
    max_replica_count: int = 1,    
):   
    aiplatform.init(project=project, location=location)

    model = aiplatform.Model(model_resource_name)

    batch_prediction_job = model.batch_predict(
        job_display_name=job_display_name,
        instances_format='csv', #json
        gcs_source=[f"{BUCKET_URI}/{input_file_name}"],
        gcs_destination_prefix=f"{BUCKET_URI}/output",
        machine_type=machine_type, # must be present      
    )
    batch_prediction_job.wait()
    print(batch_prediction_job.display_name)
    print(batch_prediction_job.state)
    return batch_prediction_job

batch_prediction_job(PROJECT_ID, REGION, model_resource_name, job_display_name, gcs_source, gcs_destination_prefix, machine_type="n1-standard-2")

# %% [markdown]
# ### Send an online prediction request
# Each prediction request must be max. 1.5 MB.

# %%
ENDPOINT_NAME="winequality_endpoint"
instance = [[7.2, 0.23, 0.32, 8.5, 0.058, 47, 132, 0.993, 3.12, 0.46]]
#instance = [[6.7,0.23,0.31,2.1,0.046,30,0.9926,3.33,0.64,10.7]]
ENDPOINT_ID = !(gcloud ai endpoints list --region=$REGION \
              --format='value(ENDPOINT_ID)'\
              --filter=display_name=$ENDPOINT_NAME \
              --sort-by=creationTimeStamp | tail -1)
ENDPOINT_ID = ENDPOINT_ID[1]

def endpoint_predict(
    project: str, location: str, instances: list, endpoint: str
):
    aiplatform.init(project=project, location=location)

    endpoint = aiplatform.Endpoint(endpoint)

    prediction = endpoint.predict(instances=instances)
    return prediction

endpoint_predict(PROJECT_ID, REGION, instance, ENDPOINT_ID)
# Out:
# Prediction(predictions=[0.0], deployed_model_id='6021040022910664704', model_version_id='1', model_resource_name='projects/531751153412/locations/europe-west1/models/7868782507527766016', explanations=None)
